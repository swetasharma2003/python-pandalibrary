# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('penguins.csv')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.species
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
df['species'].nunique()
# Out:
# 3

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df[df['species']=='Adelie'].value_counts()
# Out:
# species  island     bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Adelie   Biscoe     34.5            18.1           187.0              2900.0       Female    1
#          Torgersen  36.2            17.2           187.0              3150.0       Female    1
#          Dream      41.3            20.3           194.0              3550.0       Male      1
#                     41.5            18.5           201.0              4000.0       Male      1
#                     42.2            18.5           180.0              3550.0       Female    1
#                                                                                             ..
#                     36.0            17.1           187.0              3700.0       Female    1
#                                     17.8           195.0              3450.0       Female    1
#                                     17.9           190.0              3450.0       Female    1
# ...

# %%
len(df)
# Out:
# 344

# %%
df.flipper_length_mm.value_counts()
# Out:
# 190.0    22
# 195.0    17
# 187.0    16
# 193.0    15
# 210.0    14
# 191.0    13
# 215.0    12
# 197.0    10
# 196.0    10
# 185.0     9
# 220.0     8
# 198.0     8
# 208.0     8
# 216.0     8
# 212.0     7
# 186.0     7
# 181.0     7
# 189.0     7
# 230.0     7
# 192.0     7
# 184.0     7
# 199.0     6
# 213.0     6
# 188.0     6
# 214.0     6
# 217.0     6
# 222.0     6
# 201.0     6
# 219.0     5
# 209.0     5
# 218.0     5
# 221.0     5
# 203.0     5
# 194.0     5
# 180.0     5
# 178.0     4
# 225.0     4
# 228.0     4
# 202.0     4
# 200.0     4
# 182.0     3
# 224.0     3
# 205.0     3
# 229.0     2
# 183.0     2
# 207.0     2
# 223.0     2
# 211.0     2
# 231.0     1
# 206.0     1
# 174.0     1
# 172.0     1
# 179.0     1
# 176.0     1
# 226.0     1
# Name: flipper_length_mm, dtype: int64

# %%
df.body_mass_g.mean()
# Out:
# 4201.754385964912

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df['island'].hist()
# Out:
# <Axes: >

# %%
df[['bill_length_mm','bill_depth_mm']].plot(kind='hist',subplots=True);

# %%
sns.displot(data=df,x='flipper_length_mm',y='body_mass_g',kind='hist')

# %%
sns.scatterplot(data=df,x=df['bill_length_mm'],y=df['bill_depth_mm'],hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
df[df['sex']=='Male'].value_counts()
# Out:
# species  island     bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Adelie   Biscoe     37.6            19.1           194.0              3750.0       Male    1
# Gentoo   Biscoe     46.4            15.6           221.0              5000.0       Male    1
#                     44.4            17.3           219.0              5250.0       Male    1
#                     45.0            15.4           220.0              5050.0       Male    1
#                     45.2            15.8           215.0              5300.0       Male    1
#                                                                                           ..
# Adelie   Torgersen  39.2            19.6           195.0              4675.0       Male    1
#                     39.3            20.6           190.0              3650.0       Male    1
#                     39.7            18.4           190.0              3900.0       Male    1
# ...

# %%
df['sex'].nunique()
# Out:
# 2

# %%
z=df['sex'].value_counts()
print(z)
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
df.groupby('species')['bill_length_mm'].plot(kind='hist',alpha=0.3,legend=True)
# Out:
# species
# Adelie       Axes(0.125,0.11;0.775x0.77)
# Chinstrap    Axes(0.125,0.11;0.775x0.77)
# Gentoo       Axes(0.125,0.11;0.775x0.77)
# Name: bill_length_mm, dtype: object

# %%
df['body_mass_g'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby('species')['body_mass_g'].plot(kind='kde',legend=True)
# Out:
# species
# Adelie       Axes(0.125,0.11;0.775x0.77)
# Chinstrap    Axes(0.125,0.11;0.775x0.77)
# Gentoo       Axes(0.125,0.11;0.775x0.77)
# Name: body_mass_g, dtype: object

# %%
df['species'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='species'>

# %%
df.groupby('species')['sex'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='sex'>

# %%
df.groupby('sex')['body_mass_g'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
df.groupby('species')['body_mass_g'].mean().plot(kind='pie',legend=True)
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
df['species'].value_counts().plot(kind='bar',color='orange')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x=df['flipper_length_mm'],y=df['body_mass_g'],hue='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
df['body_mass_g'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby('species')['body_mass_g'].plot(kind='kde',legend=True)
# Out:
# species
# Adelie       Axes(0.125,0.11;0.775x0.77)
# Chinstrap    Axes(0.125,0.11;0.775x0.77)
# Gentoo       Axes(0.125,0.11;0.775x0.77)
# Name: body_mass_g, dtype: object

# %%
df.groupby('sex')['body_mass_g'].plot(kind='kde',legend=True)
# Out:
# sex
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: body_mass_g, dtype: object

# %%
dft=pd.read_csv('penguins.csv',index_col=0,parse_dates=True)

# %%
dft.head()
# Out:
#             island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie   Torgersen            39.1           18.7              181.0
# Adelie   Torgersen            39.5           17.4              186.0
# Adelie   Torgersen            40.3           18.0              195.0
# Adelie   Torgersen             NaN            NaN                NaN
# Adelie   Torgersen            36.7           19.3              193.0
#
#          body_mass_g     sex
# species
# Adelie        3750.0    Male
# Adelie        3800.0  Female
# Adelie        3250.0  Female
# Adelie           NaN     NaN
# Adelie        3450.0  Female

# %%
dft.plot()
# Out:
# <Axes: xlabel='species'>

# %%
dft.plot(subplots=True,layout=(2,3),figsize=(15,4))
# Out:
# array([[<Axes: xlabel='species'>, <Axes: xlabel='species'>,
#         <Axes: xlabel='species'>],
#        [<Axes: xlabel='species'>, <Axes: xlabel='species'>,
#         <Axes: xlabel='species'>]], dtype=object)
